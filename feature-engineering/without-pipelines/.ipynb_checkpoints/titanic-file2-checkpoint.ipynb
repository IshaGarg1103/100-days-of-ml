# %%
import pickle
import numpy as np
import pandas as pd

# %%
#decode
ohe_sex = pickle.load(open('models/ohe_sex.pkl','rb'))
ohe_embarked = pickle.load(open('models/ohe_embarked.pkl','rb'))
clf = pickle.load(open('models/clf.pkl','rb'))

# %%
#assume user input
#Pclass/gender/age/SibSp/fare/embarked
test_input= np.array([2,'male',31.0,0,0,10.5,'S'],dtype = object).reshape(1,7)
#after reshape(1,7)
#it becomes from [2, 'male', 31.0, 0, 0, 10.5, 'S'] -> [[2, 'male', 31.0, 0, 0, 10.5, 'S']]

# %%
test_input
# Out:
# array([[2, 'male', 31.0, 0, 0, 10.5, 'S']], dtype=object)

# %%
test_input_df = pd.DataFrame({'Sex':[test_input[0,1]]})

# %%
test_input_sex = ohe_sex.transform(test_input_df)

# %%
test_input_sex
# Out:
# array([[0., 1.]])

# %%
test_input_df1= pd.DataFrame({'Embarked':[test_input[0,6]]})

# %%
test_input_embarked = ohe_embarked.transform(test_input_df1.values)

# %%
cols = ['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']
test_input_df = pd.DataFrame([test_input.flatten()],columns = cols)

# %%
test_input_sex = ohe_sex.transform(test_input_df[['Sex']])

# %%
test_input_embarked = ohe_embarked.transform(test_input_df[['Embarked']])
