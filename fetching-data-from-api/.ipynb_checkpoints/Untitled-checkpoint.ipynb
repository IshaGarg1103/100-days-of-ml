# %%
import pandas as pd
import requests

# %%
requests.get(https://api.themoviedb.org/3/movie/top_rated?api_key=8156ba7859bd0552330c4491d2d52d0c&language=en-US&page=1)
# Out:
#   Cell In[2], line 1
#     requests.get(https://api.themoviedb.org/3/movie/top_rated?api_key=8156ba7859bd0552330c4491d2d52d0c&language=en-US&page=1)
#                                                                          ^
# SyntaxError: invalid decimal literal
