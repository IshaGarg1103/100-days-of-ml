# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
titanic = pd.read_csv('train.csv')

# %%
flights = sns.load_dataset('flights')

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## 1. Scatterplot(Numerical - Numerical)

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips)
plt.show()

# %% [markdown]
# #### to find out which customers are male and which customers are female

# %%
sns.scatterplot(x="total_bill", y="tip", hue = df['sex'],data=tips)
plt.show()

# %%
tips['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %% [markdown]
# #### to find out who are smokers and who aren't

# %%
sns.scatterplot(x="total_bill", y="tip", hue = df['sex'],style = df['smoker'],data=tips)
plt.show()

# %% [markdown]
# #### to differ thru their family size

# %%
sns.scatterplot(x="total_bill",y="tip",hue=df['sex'],style=df['smoker'],size=df['size'],data=tips)
plt.show()

# %% [markdown]
# ## 2. Bar Plot(Numerical-Categorical)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.barplot(x=titanic['Pclass'],y=titanic['Fare'],hue = "Pclass",palette="Set2",data=titanic)
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# #### that black rod is called confidence interval

# %%
sns.barplot(x=titanic['Pclass'],y=titanic['Fare'],hue = "Sex",palette="Set2",data=titanic)
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# ## 3. Box Plot (Numerical - Categorical)

# %%
sns.boxplot(x='Sex',y='Age',hue = 'Survived',palette='Set2',data=titanic)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# ## 4. Displot(Numerical - Categorical)

# %%
sns.histplot(titanic["Age"], kde=True,stat="density",alpha=.4,edgecolor=(1, 1, 1, .4))
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.displot(titanic[titanic["Survived"]==0]['Age'], kind="kde")
sns.displot(titanic[titanic["Survived"]==1]['Age'], kind="kde")

# %%
sns.kdeplot(titanic[titanic["Survived"]==0]['Age'])
sns.kdeplot(titanic[titanic["Survived"]==1]['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## 5. HeatMap (Categorical - Categorical)

# %%
sns.heatmap(pd.crosstab(titanic['Pclass'],titanic['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
titanic.groupby('Pclass')['Survived'].mean()*100 #percentage of survival which is grouped by Pclass
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
(titanic.groupby('Pclass')['Survived'].mean()*100).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
titanic.groupby(['Embarked', 'Pclass','Sex'])['Survived'].mean() * 100
# Out:
# Embarked  Pclass  Sex
# C         1       female     97.674419
#                   male       40.476190
#           2       female    100.000000
#                   male       20.000000
#           3       female     65.217391
#                   male       23.255814
# Q         1       female    100.000000
#                   male        0.000000
#           2       female    100.000000
#                   male        0.000000
#           3       female     72.727273
#                   male        7.692308
# S         1       female     95.833333
#                   male       35.443038
#           2       female     91.044776
#                   male       15.463918
#           3       female     37.500000
#                   male       12.830189
# Name: Survived, dtype: float64

# %%
sns.barplot(x="Embarked", y="Survived", hue="Sex", data=titanic, errorbar=None)
plt.ylabel("Survival Rate")
plt.title("Survival Rate by Embarked & Sex")
plt.show()

# %%
sns.barplot(x="Embarked", y="Survived", hue="Pclass", data=titanic, errorbar=None)
plt.ylabel("Survival Rate")
plt.title("Survival Rate by Embarked & Pclass")
plt.show()

# %%
titanic.groupby('Embarked')['Sex'].value_counts(normalize=True) * 100
# Out:
# Embarked  Sex
# C         male      56.547619
#           female    43.452381
# Q         male      53.246753
#           female    46.753247
# S         male      68.478261
#           female    31.521739
# Name: proportion, dtype: float64

# %% [markdown]
# ## 6. ClusterMap (Categorical - Categorical)

# %%
sns.clustermap(pd.crosstab(titanic['SibSp'],titanic['Survived']))

# %% [markdown]
# ## 7. Pairplot

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris,hue='species')

# %% [markdown]
# ## 8. Lineplot(Numerical - Numerical)

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.groupby('year')['passengers'].sum().reset_index()
# Out:
#     year  passengers
# 0   1949        1520
# 1   1950        1676
# 2   1951        2042
# 3   1952        2364
# 4   1953        2700
# 5   1954        2867
# 6   1955        3408
# 7   1956        3939
# 8   1957        4421
# 9   1958        4572
# 10  1959        5140
# 11  1960        5714

# %%
new=flights.groupby('year')['passengers'].sum().reset_index()

# %%
sns.lineplot(x=new['year'],y=new['passengers'])
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
flights.pivot_table(values='passengers',index='month',columns='year',observed=False)
# Out:
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# Aug    148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0  505.0
# Sep    136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0  404.0
# Oct    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0  359.0
# Nov    104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0  310.0
# ...

# %%
sns.heatmap(flights.pivot_table(values='passengers',index='month',columns='year',observed=False))
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(flights.pivot_table(values='passengers',index='month',columns='year',observed=False))
