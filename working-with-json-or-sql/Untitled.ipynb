# %%
import pandas as pd

# %% [markdown]
# ## Working with json

# %%
url = 'https://github.com/campusx-official/100-days-of-machine-learning/raw/refs/heads/main/day16%20-%20working-with-json-and-sql/train.json'
pd.read_json(url)
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %% [markdown]
# ## Working with SQL

# %%
# !pip install mysql.connector
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mysql.connector
#   Downloading mysql-connector-2.2.9.tar.gz (11.9 MB)
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      - -------------------------------------- 0.5/11.9 MB 5.6 MB/s eta 0:00:03
#      ------ --------------------------------- 1.8/11.9 MB 3.7 MB/s eta 0:00:03
#      ---------- ----------------------------- 3.1/11.9 MB 3.8 MB/s eta 0:00:03
#      --------------- ------------------------ 4.7/11.9 MB 4.7 MB/s eta 0:00:02
#      --------------------- ------------------ 6.3/11.9 MB 4.6 MB/s eta 0:00:02
#      ----------------------------- ---------- 8.7/11.9 MB 5.4 MB/s eta 0:00:01
#      ----------------------------------- ---- 10.5/11.9 MB 5.8 MB/s eta 0:00:01
#      ---------------------------------------- 11.9/11.9 MB 6.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: mysql.connector
#   Building wheel for mysql.connector (setup.py): started
#   Building wheel for mysql.connector (setup.py): finished with status 'done'
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp312-cp312-win_amd64.whl size=247959 sha256=732fc3b466fa4edbd31806801e73e301cbfa5d5763baa529b51752539540750d
#   Stored in directory: c:\users\india\appdata\local\pip\cache\wheels\03\17\fa\d7604c72dd3dd6d3eb3d249abf36cc532c9a9b4354b8f1bc4f
# Successfully built mysql.connector
# Installing collected packages: mysql.connector
# Successfully installed mysql.connector-2.2.9

# %%
import mysql.connector
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import mysql.connector
#
# ModuleNotFoundError: No module named 'mysql'

# %%
# !pip uninstall -y mysql-connector
# Out:
# Found existing installation: mysql-connector 2.2.9
# Uninstalling mysql-connector-2.2.9:
#   Successfully uninstalled mysql-connector-2.2.9

# %%
# !pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.4.0-cp312-cp312-win_amd64.whl.metadata (7.7 kB)
# Downloading mysql_connector_python-9.4.0-cp312-cp312-win_amd64.whl (16.4 MB)
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    --- ------------------------------------ 1.6/16.4 MB 7.6 MB/s eta 0:00:02
#    -------- ------------------------------- 3.4/16.4 MB 8.0 MB/s eta 0:00:02
#    ------------ --------------------------- 5.0/16.4 MB 7.9 MB/s eta 0:00:02
#    --------------- ------------------------ 6.3/16.4 MB 7.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 7.1/16.4 MB 6.9 MB/s eta 0:00:02
#    -------------------- ------------------- 8.4/16.4 MB 6.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 9.4/16.4 MB 6.6 MB/s eta 0:00:02
#    ------------------------- -------------- 10.5/16.4 MB 6.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.8/16.4 MB 6.2 MB/s eta 0:00:01
#    -------------------------------- ------- 13.4/16.4 MB 6.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.7/16.4 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  16.3/16.4 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------- 16.4/16.4 MB 6.2 MB/s eta 0:00:00
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.4.0

# %%
import mysql.connector

# %%
conn =mysql.connector.connect(host = 'localhost',user = 'root',password='',database = 'world')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\network.py:795, in MySQLTCPSocket.open_connection(self)
#     794     self.sock.settimeout(self._connection_timeout)
# --> 795     self.sock.connect(sockaddr)
#     796 except (socket.timeout, TimeoutError) as err:
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# The above exception was the direct cause of the following exception:
#
# InterfaceError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 conn =mysql.connector.connect(host = 'localhost',user = 'root',password='',database = 'world')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\pooling.py:323, in connect(*args, **kwargs)
#     321 if CMySQLConnection and not use_pure:
#     322     return CMySQLConnection(*args, **kwargs)
# --> 323 return MySQLConnection(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\connection.py:185, in MySQLConnection.__init__(self, **kwargs)
#     183 if kwargs:
#     184     try:
# --> 185         self.connect(**kwargs)
#     186     except Exception:
#     187         # Tidy-up underlying socket on failure
#     188         self.close()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\abstracts.py:1604, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1601     self.config(**kwargs)
#    1603 self.disconnect()
# -> 1604 self._open_connection()
#    1606 charset, collation = (
#    1607     kwargs.pop("charset", None),
#    1608     kwargs.pop("collation", None),
#    1609 )
#    1610 if charset or collation:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\connection.py:411, in MySQLConnection._open_connection(self)
#     406     if isinstance(err, (ReadTimeoutError, WriteTimeoutError)):
#     407         raise ConnectionTimeoutError(
#     408             errno=err.errno,
#     409             msg=err.msg,
#     410         ) from err
# --> 411     raise err
#     412 finally:
#     413     # as the connection is established, set back the read
#     414     # and write timeouts to the original value
#     415     self.read_timeout = stored_read_timeout
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\connection.py:382, in MySQLConnection._open_connection(self)
#     380 self._socket = self._get_connection()
#     381 try:
# --> 382     self._socket.open_connection()
#     384     # do initial handshake
#     385     self._do_handshake()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\network.py:806, in MySQLTCPSocket.open_connection(self)
#     797     raise ConnectionTimeoutError(
#     798         errno=2003,
#     799         values=(
#    (...)
#     803         ),
#     804     ) from err
#     805 except IOError as err:
# --> 806     raise InterfaceError(
#     807         errno=2003,
#     808         values=(self.server_host, self.server_port, _strioerror(err)),
#     809     ) from err
#     810 except Exception as err:
#     811     raise InterfaceError(str(err)) from err
#
# InterfaceError: 2003: Can't connect to MySQL server on 'localhost:3306' (Errno 10061: No connection could be made because the target machine actively refused it)

# %%
pd.read_sql_query('SELECT * FROM city',conn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pd.read_sql_query('SELECT * FROM city',conn)
#
# NameError: name 'pd' is not defined
